# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_user_attributes = _hex_json.loads("{}")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"UTC\"")

# %%
hex_project_id = _hex_json.loads("\"0196c58b-b00d-7116-a2aa-464d145e7ab8\"")

# %%
hex_project_name = _hex_json.loads("\"Simulated Supabase Product Insights\"")

# %%
hex_status = _hex_json.loads("\"Completed\"")

# %%
hex_categories = _hex_json.loads("[\"Dashboard\"]")

# %%
hex_color_palette = _hex_json.loads("[\"#4C78A8\",\"#F58518\",\"#E45756\",\"#72B7B2\",\"#54A24B\",\"#EECA3B\",\"#B279A2\",\"#FF9DA6\",\"#9D755D\",\"#BAB0AC\"]")

# %% [markdown]
# ### KPIs

# %%
# import jinja2
# raw_query = """
#     select count(*) as total_users
#     from postgres.supabase_funnel_supabase_funnel.fct_users;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
total_users

# %%
# import jinja2
# raw_query = """
#     -- % of users with at least one paid billing event
#     select 
#       round(1.0 * count(distinct user_id) / 
#         (select count(*) from supabase_funnel_supabase_funnel.fct_users), 3) as percent_upgraded
#     from supabase_funnel_supabase_funnel.fct_billing
#     where amount > 0
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
users_upgraded_pct

# %%
# import jinja2
# raw_query = """
#     select 
#       billing_month,
#       sum(mrr) as mrr
#     from supabase_funnel_supabase_funnel.int_mrr_by_month
#     group by billing_month
#     order by billing_month desc
#     limit 1
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
latest_mrr

# %%
# import jinja2
# raw_query = """
#     WITH cohort_retention AS (
#       SELECT
#         signup_week,
#         SUM(CASE WHEN week_number = 1 THEN retained_users ELSE 0 END) AS week_0_users,
#         SUM(CASE WHEN week_number = 2 THEN retained_users ELSE 0 END) AS week_1_users
#       FROM supabase_funnel_supabase_funnel.int_retention_cohorts
#       GROUP BY signup_week
#     )
#     SELECT
#       ROUND(1.0 * AVG(week_1_users * 1.0 / NULLIF(week_0_users, 0)), 4) AS week_1_retention_rate
#     FROM cohort_retention;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
weekly_retention_rate

# %% [markdown]
# ### **Activation Funnel**

# %%
# import jinja2
# raw_query = """
#     with base as (
#       select 
#         user_id,
#         signup_date,
#         first_project_date,
#         first_feature_use
#       from supabase_funnel_supabase_funnel.int_activation_funnel
#     ),
#     
#     funnel as (
#       select
#         'Signed Up' as stage,
#         count(*) as users
#       from base
#     
#       union all
#     
#       select
#         'Created Project' as stage,
#         count(*) 
#       from base
#       where first_project_date is not null
#     
#       union all
#     
#       select
#         'Used Feature' as stage,
#         count(*)
#       from base
#       where first_feature_use is not null
#     )
#     
#     select *
#     from funnel
#     order by case stage 
#       when 'Signed Up' then 1
#       when 'Created Project' then 2
#       when 'Used Feature' then 3
#     end
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_funnel_drop_off = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "description": "outer data layer",
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "description": "series data layer",
                    "name": "series_0196c67c-34e9-755a-b2fa-1d3402531814",
                    "layer": [
                        {
                            "description": "bar series layer",
                            "transform": [
                                {
                                    "joinaggregate": [
                                        {
                                            "field": "users",
                                            "op": "sum",
                                            "as": "sum_y_by_x"
                                        }
                                    ],
                                    "groupby": [
                                        "stage"
                                    ]
                                }
                            ],
                            "layer": [
                                {
                                    "description": "bar mark layer",
                                    "mark": {
                                        "type": "bar",
                                        "clip": true,
                                        "filled": true,
                                        "cursor": "pointer",
                                        "orient": "horizontal"
                                    },
                                    "params": [
                                        {
                                            "name": "interval_intervalselection_0",
                                            "select": {
                                                "type": "interval",
                                                "encodings": [
                                                    "y"
                                                ],
                                                "mark": {
                                                    "fill": "#669EFF",
                                                    "fillOpacity": 0.07,
                                                    "stroke": "#669EFF",
                                                    "strokeOpacity": 0.4
                                                },
                                                "zoom": false
                                            }
                                        },
                                        {
                                            "name": "click_pointselection_0",
                                            "select": {
                                                "type": "point",
                                                "encodings": [
                                                    "y"
                                                ]
                                            }
                                        }
                                    ],
                                    "encoding": {
                                        "opacity": {
                                            "condition": {
                                                "test": {
                                                    "not": {
                                                        "and": [
                                                            {
                                                                "param": "interval_intervalselection_0"
                                                            },
                                                            {
                                                                "param": "click_pointselection_0"
                                                            }
                                                        ]
                                                    }
                                                },
                                                "value": 0.3
                                            },
                                            "value": 1
                                        },
                                        "tooltip": [
                                            {
                                                "field": "stage",
                                                "type": "ordinal",
                                                "format": {
                                                    "year": "%Y",
                                                    "quarter": "%b %d",
                                                    "month": "%b %d",
                                                    "week": "%b %d",
                                                    "day": "%b %d"
                                                },
                                                "title": "Stage"
                                            },
                                            {
                                                "field": "users",
                                                "type": "quantitative",
                                                "aggregate": "sum",
                                                "formatType": "NUMBER_FORMATTER",
                                                "format": {
                                                    "format": "NUMBER",
                                                    "currency": "USD",
                                                    "columnType": "NUMBER",
                                                    "showSeparators": false,
                                                    "numDecimalDigits": -1,
                                                    "abbreviateLargeNumbers": false,
                                                    "nanFormat": ""
                                                },
                                                "title": "User Count"
                                            }
                                        ],
                                        "color": {
                                            "value": "#4C78A8"
                                        },
                                        "x": {
                                            "field": "users",
                                            "type": "quantitative",
                                            "aggregate": "sum",
                                            "title": "User Count",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "tickMinStep": 500,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "format": "NUMBER",
                                                    "currency": "USD",
                                                    "columnType": "NUMBER",
                                                    "showSeparators": false,
                                                    "numDecimalDigits": -1,
                                                    "abbreviateLargeNumbers": false,
                                                    "nanFormat": ""
                                                },
                                                "formatType": "NUMBER_FORMATTER"
                                            },
                                            "stack": "zero"
                                        },
                                        "y": {
                                            "field": "stage",
                                            "type": "ordinal",
                                            "title": "Stage",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "year": "%Y",
                                                    "quarter": "%b %d",
                                                    "month": "%b %d",
                                                    "week": "%b %d",
                                                    "day": "%b %d"
                                                },
                                                "labelOverlap": "greedy"
                                            },
                                            "sort": [
                                                "Signed Up",
                                                "Created Project",
                                                "Used Feature"
                                            ]
                                        }
                                    }
                                },
                                {
                                    "description": "data label text mark layer",
                                    "mark": {
                                        "type": "text",
                                        "fill": "#ffffff",
                                        "dy": {
                                            "expr": "datum[\"sum_users\"] < 0 ? 0 : 0"
                                        },
                                        "dx": {
                                            "expr": "datum[\"sum_users\"] < 0 ? 4 : -4"
                                        },
                                        "align": {
                                            "expr": "datum[\"sum_users\"] > 0 ? 'right' : 'left'"
                                        },
                                        "clip": false
                                    },
                                    "transform": [
                                        {
                                            "filter": "isValid(datum[\"users\"])"
                                        }
                                    ],
                                    "encoding": {
                                        "text": {
                                            "field": "users",
                                            "aggregate": "sum",
                                            "type": "quantitative",
                                            "format": {
                                                "format": "NUMBER",
                                                "currency": "USD",
                                                "columnType": "NUMBER",
                                                "showSeparators": false,
                                                "numDecimalDigits": -1,
                                                "abbreviateLargeNumbers": false,
                                                "nanFormat": ""
                                            },
                                            "formatType": "NUMBER_FORMATTER"
                                        },
                                        "color": {
                                            "value": "#4C78A8"
                                        },
                                        "x": {
                                            "field": "users",
                                            "type": "quantitative",
                                            "aggregate": "sum",
                                            "title": "User Count",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "tickMinStep": 500,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "format": "NUMBER",
                                                    "currency": "USD",
                                                    "columnType": "NUMBER",
                                                    "showSeparators": false,
                                                    "numDecimalDigits": -1,
                                                    "abbreviateLargeNumbers": false,
                                                    "nanFormat": ""
                                                },
                                                "formatType": "NUMBER_FORMATTER"
                                            },
                                            "stack": "zero"
                                        },
                                        "detail": {}
                                    }
                                }
                            ],
                            "encoding": {
                                "x": {
                                    "field": "users",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "User Count",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "tickMinStep": 500,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "format": "NUMBER",
                                            "currency": "USD",
                                            "columnType": "NUMBER",
                                            "showSeparators": false,
                                            "numDecimalDigits": -1,
                                            "abbreviateLargeNumbers": false,
                                            "nanFormat": ""
                                        },
                                        "formatType": "NUMBER_FORMATTER"
                                    },
                                    "stack": "zero"
                                },
                                "y": {
                                    "field": "stage",
                                    "type": "ordinal",
                                    "title": "Stage",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "year": "%Y",
                                            "quarter": "%b %d",
                                            "month": "%b %d",
                                            "week": "%b %d",
                                            "day": "%b %d"
                                        },
                                        "labelOverlap": "greedy"
                                    },
                                    "sort": [
                                        "Signed Up",
                                        "Created Project",
                                        "Used Feature"
                                    ]
                                }
                            }
                        }
                    ]
                }
            ],
            "transform": []
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_0": {
                "type": "interval",
                "datetimeFields": [],
                "derived": []
            },
            "click_pointselection_0": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            }
        },
        "columnNameMappings": {
            "CHART_FOLD_KEYS": "Column",
            "CHART_FOLD_VALUES": "Values"
        }
    }
}
""")
chart_funnel_drop_off.datasets.layer00 = funnel_drop_off.to_json(orient='records')
chart_funnel_drop_off.display(actions=False)

# %% [markdown]
# ### Retention Trends

# %%
# import jinja2
# raw_query = """
#     select 
#       activity_date,
#       dau,
#       wau,
#       mau
#     from supabase_funnel_supabase_funnel.int_retention_metrics
#     order by activity_date
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_dau_mau_wau = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "description": "outer data layer",
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "description": "series data layer",
                    "name": "series_0196c688-0f62-755a-b2fe-afb9be3efaec",
                    "layer": [
                        {
                            "description": "line series layer",
                            "transform": [
                                {
                                    "fold": [
                                        "dau",
                                        "mau",
                                        "wau"
                                    ],
                                    "as": [
                                        "CHART_FOLD_KEYS",
                                        "CHART_FOLD_VALUES"
                                    ]
                                },
                                {
                                    "calculate": "if(datum[\"CHART_FOLD_KEYS\"] === \"dau\", \"dau\", if(datum[\"CHART_FOLD_KEYS\"] === \"mau\", \"mau\", if(datum[\"CHART_FOLD_KEYS\"] === \"wau\", \"wau\", \"\")))",
                                    "as": "CHART_FOLD_KEYS"
                                },
                                {
                                    "joinaggregate": [
                                        {
                                            "field": "CHART_FOLD_VALUES",
                                            "op": "sum",
                                            "as": "sum_y_by_x"
                                        }
                                    ],
                                    "groupby": [
                                        "activity_date"
                                    ]
                                },
                                {
                                    "calculate": "toDate(datum[\"activity_date\"])",
                                    "as": "activity_date"
                                },
                                {
                                    "filter": "isValid(datum[\"activity_date\"])"
                                }
                            ],
                            "layer": [
                                {
                                    "description": "line mark layer",
                                    "mark": {
                                        "type": "line",
                                        "point": false,
                                        "clip": true,
                                        "strokeCap": "square",
                                        "strokeJoin": "round",
                                        "cursor": "crosshair"
                                    },
                                    "params": [
                                        {
                                            "name": "interval_intervalselection_0",
                                            "select": {
                                                "type": "interval",
                                                "encodings": [
                                                    "x"
                                                ],
                                                "zoom": false,
                                                "mark": {
                                                    "fill": "#669EFF",
                                                    "fillOpacity": 0.07,
                                                    "stroke": "#669EFF",
                                                    "strokeOpacity": 0.4
                                                }
                                            }
                                        },
                                        {
                                            "name": "legend_pointselection_0",
                                            "select": {
                                                "type": "point",
                                                "encodings": [
                                                    "color"
                                                ]
                                            },
                                            "bind": "legend"
                                        },
                                        {
                                            "name": "legend_pointhover_0",
                                            "select": {
                                                "type": "point",
                                                "encodings": [
                                                    "color"
                                                ]
                                            },
                                            "bind": "legend"
                                        }
                                    ],
                                    "encoding": {
                                        "opacity": {
                                            "value": 1
                                        }
                                    }
                                },
                                {
                                    "description": "line point mark layer",
                                    "mark": {
                                        "type": "point",
                                        "filled": true,
                                        "clip": true
                                    },
                                    "encoding": {
                                        "size": {
                                            "value": 50
                                        },
                                        "opacity": {
                                            "condition": {
                                                "test": {
                                                    "or": [
                                                        {
                                                            "param": "legend_pointhover_0",
                                                            "empty": false
                                                        }
                                                    ],
                                                    "empty": false
                                                },
                                                "value": 1
                                            },
                                            "value": 0
                                        }
                                    }
                                },
                                {
                                    "description": "pivot tooltip point mark layer",
                                    "mark": {
                                        "type": "point",
                                        "tooltip": true,
                                        "clip": true
                                    },
                                    "encoding": {
                                        "opacity": {
                                            "value": 0,
                                            "condition": {
                                                "param": "pivot_hover_0196c688-0f62-755a-b2fe-afb9be3efaec",
                                                "value": 1,
                                                "empty": false
                                            }
                                        },
                                        "size": {
                                            "value": 80
                                        },
                                        "tooltip": [
                                            {
                                                "field": "activity_date",
                                                "type": "temporal",
                                                "formatType": "DATETIME_FORMATTER",
                                                "format": {
                                                    "format": "DATE_ISO8601",
                                                    "timezone": "IGNORE",
                                                    "columnType": "DATETIME"
                                                },
                                                "timeUnit": "yearmonthdate",
                                                "title": "Date"
                                            },
                                            {
                                                "field": "CHART_FOLD_VALUES",
                                                "type": "quantitative",
                                                "formatType": "NUMBER_FORMATTER",
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "title": "Active Users"
                                            },
                                            {
                                                "field": "CHART_FOLD_KEYS",
                                                "type": "ordinal",
                                                "title": "Column"
                                            }
                                        ]
                                    },
                                    "params": [
                                        {
                                            "name": "pivot_hover_0196c688-0f62-755a-b2fe-afb9be3efaec",
                                            "select": {
                                                "type": "point",
                                                "on": "mouseover",
                                                "clear": "mouseout",
                                                "nearest": true,
                                                "fields": [
                                                    "activity_date",
                                                    "CHART_FOLD_KEYS",
                                                    "CHART_FOLD_KEYS"
                                                ]
                                            }
                                        }
                                    ]
                                }
                            ],
                            "encoding": {
                                "x": {
                                    "field": "activity_date",
                                    "type": "temporal",
                                    "title": "Date",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "tickCount": 15,
                                        "labels": true,
                                        "labelAngle": -40,
                                        "labelFlush": false,
                                        "format": {
                                            "format": "DATE_ISO8601",
                                            "timezone": "IGNORE",
                                            "columnType": "DATETIME"
                                        },
                                        "formatType": "DATETIME_FORMATTER"
                                    },
                                    "timeUnit": "yearmonthdate"
                                },
                                "y": {
                                    "field": "CHART_FOLD_VALUES",
                                    "type": "quantitative",
                                    "title": "Active Users",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "format": "NUMBER",
                                            "columnType": "NUMBER",
                                            "numDecimalDigits": -1,
                                            "currency": "USD",
                                            "nanFormat": ""
                                        },
                                        "formatType": "NUMBER_FORMATTER"
                                    }
                                },
                                "color": {
                                    "field": "CHART_FOLD_KEYS",
                                    "scale": {
                                        "range": [
                                            "#4C78A8",
                                            "#F58518",
                                            "#E45756",
                                            "#72B7B2",
                                            "#54A24B",
                                            "#EECA3B",
                                            "#B279A2",
                                            "#FF9DA6",
                                            "#9D755D",
                                            "#BAB0AC"
                                        ]
                                    },
                                    "sort": {
                                        "field": "CHART_FOLD_KEYS",
                                        "order": "ascending"
                                    },
                                    "legend": {
                                        "symbolOpacity": 1,
                                        "symbolType": "stroke"
                                    },
                                    "title": null
                                },
                                "detail": [
                                    {
                                        "field": "CHART_FOLD_KEYS",
                                        "type": "ordinal",
                                        "title": "Column"
                                    }
                                ]
                            }
                        }
                    ]
                }
            ],
            "transform": []
        }
    ],
    "config": {
        "legend": {
            "orient": "top-right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_0": {
                "type": "interval",
                "datetimeFields": [
                    "yearmonthdate_activity_date"
                ],
                "derived": [
                    {
                        "type": "timeunit",
                        "sourceName": "activity_date",
                        "derivedName": "yearmonthdate_activity_date",
                        "timeUnit": "yearmonthdate"
                    }
                ]
            }
        },
        "columnNameMappings": {
            "CHART_FOLD_KEYS": "Column",
            "CHART_FOLD_VALUES": "Values"
        }
    }
}
""")
chart_dau_mau_wau.datasets.layer00 = dau_mau_wau.to_json(orient='records')
chart_dau_mau_wau.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     with base as (
#       select 
#         signup_week,
#         week_number,
#         retained_users
#       from supabase_funnel_supabase_funnel.int_retention_cohorts
#     ),
#     
#     cohort_base as (
#       select 
#         signup_week,
#         max(case when week_number = 1 then retained_users end) as cohort_size
#       from base
#       group by signup_week
#     ),
#     
#     joined as (
#       select 
#         b.signup_week,
#         b.week_number,
#         b.retained_users,
#         c.cohort_size,
#         round(1.0 * b.retained_users::numeric / nullif(c.cohort_size, 4), 1) as retention_rate
#       from base b
#       join cohort_base c using (signup_week)
#       where b.week_number > 0
#     )
#     
#     select *
#     from joined
#     order by signup_week, week_number;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select "week_number" as "Week",
#            cast(date_trunc('day', cast("signup_week" as timestamptz)) as date) as "Signup Week",
#            sum("retention_rate") as "Retention Rate"
#     from retention_cohort_grid
#     group by "Week",
#              "Signup Week"
# """
# sql_query = jinja2.Template(raw_query).render(vars())

pivot_table_df = sql_query_result.pivot(
    index=["Week"],
    columns=["Signup Week"],
    values=["Retention Rate"],
)

# pandas.pivot puts the values on the top level of the column hierarchy
# reorder them to the bottom
pivot_table_df = pivot_table_df.reorder_levels(
    order=[1, 0],
    axis="columns",
)

# replace NaNs with 0
pivot_table_df.fillna(value=0, inplace=True)

# Sort pivot table columns
pivot_table_df.sort_index(
    axis="columns",
    level=[0, 1],
    ascending=[True, True],
    inplace=True,
)

# Sort pivot table rows
pivot_table_df.sort_index(
    axis="rows",
    level=[0],
    ascending=True,
    inplace=True,
)

# %% [markdown]
# ### Monetization

# %%
# import jinja2
# raw_query = """
#     select 
#       billing_month,
#       sum(mrr) as mrr
#     from supabase_funnel_supabase_funnel.int_mrr_by_month
#     group by billing_month
#     order by billing_month
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_mrr_by_month = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "description": "outer data layer",
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "description": "series data layer",
                    "name": "series_0196c694-c332-755a-b308-3001630b50a1",
                    "layer": [
                        {
                            "description": "line series layer",
                            "transform": [
                                {
                                    "joinaggregate": [
                                        {
                                            "field": "mrr",
                                            "op": "sum",
                                            "as": "sum_y_by_x"
                                        }
                                    ],
                                    "groupby": [
                                        "billing_month"
                                    ]
                                },
                                {
                                    "calculate": "toDate(datum[\"billing_month\"])",
                                    "as": "billing_month"
                                },
                                {
                                    "filter": "isValid(datum[\"billing_month\"])"
                                }
                            ],
                            "layer": [
                                {
                                    "description": "line mark layer",
                                    "mark": {
                                        "type": "line",
                                        "point": false,
                                        "clip": true,
                                        "strokeCap": "square",
                                        "strokeJoin": "round",
                                        "cursor": "crosshair"
                                    },
                                    "params": [
                                        {
                                            "name": "interval_intervalselection_0",
                                            "select": {
                                                "type": "interval",
                                                "encodings": [
                                                    "x"
                                                ],
                                                "zoom": false,
                                                "mark": {
                                                    "fill": "#669EFF",
                                                    "fillOpacity": 0.07,
                                                    "stroke": "#669EFF",
                                                    "strokeOpacity": 0.4
                                                }
                                            }
                                        }
                                    ],
                                    "encoding": {
                                        "opacity": {
                                            "value": 1
                                        }
                                    }
                                },
                                {
                                    "description": "pivot tooltip point mark layer",
                                    "mark": {
                                        "type": "point",
                                        "tooltip": false,
                                        "clip": true
                                    },
                                    "encoding": {
                                        "opacity": {
                                            "value": 0,
                                            "condition": {
                                                "param": "pivot_hover_0196c694-c332-755a-b308-3001630b50a1",
                                                "value": 1,
                                                "empty": false
                                            }
                                        },
                                        "size": {
                                            "value": 80
                                        }
                                    }
                                },
                                {
                                    "description": "pivot tooltip rule mark layer",
                                    "mark": {
                                        "type": "rule",
                                        "clip": true
                                    },
                                    "encoding": {
                                        "opacity": {
                                            "condition": {
                                                "value": 0.3,
                                                "param": "pivot_hover_0196c694-c332-755a-b308-3001630b50a1",
                                                "empty": false
                                            },
                                            "value": 0
                                        },
                                        "color": {
                                            "value": "CHART_DEFAULT_RULE_COLOR_MARKER"
                                        },
                                        "y": null,
                                        "tooltip": [
                                            {
                                                "field": "billing_month",
                                                "type": "temporal",
                                                "timeUnit": "yearmonth",
                                                "title": "Billing Month"
                                            },
                                            {
                                                "field": "mrr",
                                                "type": "quantitative",
                                                "aggregate": "sum",
                                                "formatType": "NUMBER_FORMATTER",
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "title": "MRR"
                                            }
                                        ]
                                    },
                                    "params": [
                                        {
                                            "name": "pivot_hover_0196c694-c332-755a-b308-3001630b50a1",
                                            "select": {
                                                "type": "point",
                                                "on": "mouseover",
                                                "clear": "mouseout",
                                                "nearest": true,
                                                "fields": [
                                                    "billing_month"
                                                ]
                                            }
                                        }
                                    ]
                                }
                            ],
                            "encoding": {
                                "x": {
                                    "field": "billing_month",
                                    "type": "temporal",
                                    "title": "Billing Month",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "tickCount": {
                                            "expr": "length(domain('x')) > 0 ? min(ceil(width / 40), ceil((domain('x')[1] - domain('x')[0]) / 2592000000)) : ceil(width / 40)"
                                        },
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "timeUnit": "yearmonth"
                                },
                                "y": {
                                    "field": "mrr",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "MRR",
                                    "scale": {
                                        "type": "linear"
                                    },
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "format": "NUMBER",
                                            "columnType": "NUMBER",
                                            "numDecimalDigits": -1,
                                            "currency": "USD",
                                            "nanFormat": ""
                                        },
                                        "formatType": "NUMBER_FORMATTER"
                                    }
                                },
                                "color": {
                                    "value": "#4C78A8"
                                }
                            }
                        }
                    ]
                }
            ],
            "transform": []
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_0": {
                "type": "interval",
                "datetimeFields": [
                    "yearmonth_billing_month"
                ],
                "derived": [
                    {
                        "type": "timeunit",
                        "sourceName": "billing_month",
                        "derivedName": "yearmonth_billing_month",
                        "timeUnit": "yearmonth"
                    }
                ]
            }
        },
        "columnNameMappings": {
            "CHART_FOLD_KEYS": "Column",
            "CHART_FOLD_VALUES": "Values"
        }
    }
}
""")
chart_mrr_by_month.datasets.layer00 = mrr_by_month.to_json(orient='records')
chart_mrr_by_month.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     select 
#       date_trunc('month', upgrade_date) as month,
#       count(*) as upgraded_users
#     from supabase_funnel_supabase_funnel.int_monetization_metrics
#     where upgrade_date is not null
#     group by month
#     order by month
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_upgrade_count_by_month = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "description": "outer data layer",
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "description": "series data layer",
                    "name": "series_0196c696-a506-755a-b309-673c75155638",
                    "layer": [
                        {
                            "description": "bar series layer",
                            "transform": [
                                {
                                    "joinaggregate": [
                                        {
                                            "field": "upgraded_users",
                                            "op": "sum",
                                            "as": "sum_y_by_x"
                                        }
                                    ],
                                    "groupby": [
                                        "month"
                                    ]
                                },
                                {
                                    "calculate": "toDate(datum[\"month\"])",
                                    "as": "month"
                                },
                                {
                                    "filter": "isValid(datum[\"month\"])"
                                }
                            ],
                            "layer": [
                                {
                                    "description": "bar mark layer",
                                    "mark": {
                                        "type": "bar",
                                        "clip": true,
                                        "filled": true,
                                        "cursor": "pointer",
                                        "orient": "horizontal"
                                    },
                                    "params": [
                                        {
                                            "name": "interval_intervalselection_0",
                                            "select": {
                                                "type": "interval",
                                                "encodings": [
                                                    "y"
                                                ],
                                                "mark": {
                                                    "fill": "#669EFF",
                                                    "fillOpacity": 0.07,
                                                    "stroke": "#669EFF",
                                                    "strokeOpacity": 0.4
                                                },
                                                "zoom": false
                                            }
                                        },
                                        {
                                            "name": "click_pointselection_0",
                                            "select": {
                                                "type": "point",
                                                "encodings": [
                                                    "y"
                                                ]
                                            }
                                        }
                                    ],
                                    "encoding": {
                                        "opacity": {
                                            "condition": {
                                                "test": {
                                                    "not": {
                                                        "and": [
                                                            {
                                                                "param": "interval_intervalselection_0"
                                                            },
                                                            {
                                                                "param": "click_pointselection_0"
                                                            }
                                                        ]
                                                    }
                                                },
                                                "value": 0.3
                                            },
                                            "value": 1
                                        },
                                        "tooltip": [
                                            {
                                                "field": "month",
                                                "type": "temporal",
                                                "timeUnit": "yearmonth",
                                                "title": "Month"
                                            },
                                            {
                                                "field": "upgraded_users",
                                                "type": "quantitative",
                                                "formatType": "NUMBER_FORMATTER",
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "title": "Upgraded Users"
                                            }
                                        ],
                                        "color": {
                                            "value": "#4C78A8"
                                        },
                                        "x": {
                                            "field": "upgraded_users",
                                            "type": "quantitative",
                                            "title": "Upgraded Users",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "tickMinStep": 20,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "formatType": "NUMBER_FORMATTER"
                                            },
                                            "stack": "zero"
                                        },
                                        "y": {
                                            "field": "month",
                                            "type": "temporal",
                                            "title": "Month",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "tickCount": {
                                                    "expr": "length(domain('y')) > 0 ? min(ceil(width / 40), ceil((domain('y')[1] - domain('y')[0]) / 2592000000)) : ceil(width / 40)"
                                                },
                                                "labels": true,
                                                "labelFlush": false
                                            },
                                            "timeUnit": "yearmonth",
                                            "bandPosition": 0
                                        }
                                    }
                                },
                                {
                                    "description": "data label text mark layer",
                                    "mark": {
                                        "type": "text",
                                        "fill": "#ffffff",
                                        "dy": {
                                            "expr": "datum[\"sum_upgraded_users\"] < 0 ? 0 : 0"
                                        },
                                        "dx": {
                                            "expr": "datum[\"sum_upgraded_users\"] < 0 ? 4 : -4"
                                        },
                                        "align": {
                                            "expr": "datum[\"sum_upgraded_users\"] > 0 ? 'right' : 'left'"
                                        },
                                        "clip": false
                                    },
                                    "transform": [
                                        {
                                            "filter": "isValid(datum[\"upgraded_users\"])"
                                        }
                                    ],
                                    "encoding": {
                                        "text": {
                                            "field": "upgraded_users",
                                            "aggregate": "sum",
                                            "type": "quantitative",
                                            "format": {
                                                "format": "NUMBER",
                                                "columnType": "NUMBER",
                                                "numDecimalDigits": -1,
                                                "currency": "USD",
                                                "nanFormat": ""
                                            },
                                            "formatType": "NUMBER_FORMATTER"
                                        },
                                        "color": {
                                            "value": "#4C78A8"
                                        },
                                        "x": {
                                            "field": "upgraded_users",
                                            "type": "quantitative",
                                            "aggregate": "sum",
                                            "title": "Upgraded Users",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "tickMinStep": 20,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "formatType": "NUMBER_FORMATTER"
                                            },
                                            "stack": "zero"
                                        },
                                        "detail": {}
                                    }
                                }
                            ],
                            "encoding": {
                                "x": {
                                    "field": "upgraded_users",
                                    "type": "quantitative",
                                    "title": "Upgraded Users",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "tickMinStep": 20,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "format": "NUMBER",
                                            "columnType": "NUMBER",
                                            "numDecimalDigits": -1,
                                            "currency": "USD",
                                            "nanFormat": ""
                                        },
                                        "formatType": "NUMBER_FORMATTER"
                                    },
                                    "stack": "zero"
                                },
                                "y": {
                                    "field": "month",
                                    "type": "temporal",
                                    "title": "Month",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "tickCount": {
                                            "expr": "length(domain('y')) > 0 ? min(ceil(width / 40), ceil((domain('y')[1] - domain('y')[0]) / 2592000000)) : ceil(width / 40)"
                                        },
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "timeUnit": "yearmonth"
                                }
                            }
                        }
                    ]
                }
            ],
            "transform": []
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_0": {
                "type": "interval",
                "datetimeFields": [
                    "yearmonth_month"
                ],
                "derived": [
                    {
                        "type": "timeunit",
                        "sourceName": "month",
                        "derivedName": "yearmonth_month",
                        "timeUnit": "yearmonth"
                    }
                ]
            },
            "click_pointselection_0": {
                "type": "point",
                "datetimeFields": [
                    "yearmonth_month"
                ],
                "derived": [
                    {
                        "type": "timeunit",
                        "sourceName": "month",
                        "derivedName": "yearmonth_month",
                        "timeUnit": "yearmonth"
                    }
                ]
            }
        },
        "columnNameMappings": {
            "CHART_FOLD_KEYS": "Column",
            "CHART_FOLD_VALUES": "Values"
        }
    }
}
""")
chart_upgrade_count_by_month.datasets.layer00 = upgrade_count_by_month.to_json(orient='records')
chart_upgrade_count_by_month.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     select 
#       plan,
#       count(*) as users
#     from supabase_funnel_supabase_funnel.int_monetization_metrics
#     group by plan
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_freemium_vs_paid = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "description": "outer data layer",
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "description": "series data layer",
                    "name": "series_0196c69a-990e-755a-b30b-28d6e0eca074",
                    "layer": [
                        {
                            "description": "pie arc mark layer",
                            "mark": {
                                "type": "arc",
                                "cursor": "pointer",
                                "innerRadius": {
                                    "expr": "0 * (min(width, height) / 2)"
                                }
                            },
                            "params": [
                                {
                                    "name": "legend_pointselection_0",
                                    "select": {
                                        "type": "point",
                                        "encodings": [
                                            "color"
                                        ]
                                    },
                                    "bind": "legend"
                                },
                                {
                                    "name": "legend_pointhover_0",
                                    "select": {
                                        "type": "point",
                                        "encodings": [
                                            "color"
                                        ]
                                    },
                                    "bind": "legend"
                                },
                                {
                                    "name": "click_pointselection_0",
                                    "select": {
                                        "type": "point",
                                        "encodings": [
                                            "color"
                                        ]
                                    }
                                }
                            ],
                            "encoding": {
                                "theta": {
                                    "field": "users",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "stack": true
                                },
                                "color": {
                                    "field": "plan",
                                    "scale": {
                                        "range": [
                                            "#4C78A8",
                                            "#F58518",
                                            "#E45756",
                                            "#72B7B2",
                                            "#54A24B",
                                            "#EECA3B",
                                            "#B279A2",
                                            "#FF9DA6",
                                            "#9D755D",
                                            "#BAB0AC"
                                        ]
                                    },
                                    "sort": {
                                        "field": "plan",
                                        "order": "ascending"
                                    },
                                    "legend": {
                                        "symbolOpacity": 1
                                    },
                                    "title": null,
                                    "type": "ordinal"
                                },
                                "opacity": {
                                    "condition": {
                                        "test": {
                                            "not": {
                                                "and": [
                                                    {
                                                        "or": [
                                                            {
                                                                "param": "legend_pointselection_0",
                                                                "empty": false
                                                            },
                                                            {
                                                                "param": "legend_pointhover_0"
                                                            }
                                                        ]
                                                    },
                                                    {
                                                        "param": "click_pointselection_0"
                                                    }
                                                ]
                                            }
                                        },
                                        "value": 0.3
                                    },
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "plan",
                                        "type": "ordinal",
                                        "title": "plan"
                                    },
                                    {
                                        "field": "users",
                                        "type": "quantitative",
                                        "aggregate": "sum",
                                        "formatType": "NUMBER_FORMATTER",
                                        "format": {
                                            "format": "NUMBER",
                                            "columnType": "NUMBER",
                                            "numDecimalDigits": -1,
                                            "currency": "USD",
                                            "nanFormat": ""
                                        },
                                        "title": "Sum of users"
                                    },
                                    {
                                        "field": "pct_transform",
                                        "type": "quantitative",
                                        "aggregate": "sum",
                                        "formatType": "NUMBER_FORMATTER",
                                        "format": {
                                            "format": "PERCENT_2SIGFIG",
                                            "columnType": "NUMBER",
                                            "numDecimalDigits": 0,
                                            "currency": "USD",
                                            "abbreviateLargeNumbers": false,
                                            "nanFormat": ""
                                        },
                                        "title": "% of Sum of users"
                                    }
                                ],
                                "order": {
                                    "field": "plan",
                                    "sort": "ascending"
                                }
                            },
                            "transform": [
                                {
                                    "aggregate": [
                                        {
                                            "op": "sum",
                                            "field": "users",
                                            "as": "aggregate_transform"
                                        }
                                    ],
                                    "groupby": [
                                        "plan"
                                    ]
                                },
                                {
                                    "joinaggregate": [
                                        {
                                            "op": "sum",
                                            "field": "aggregate_transform",
                                            "as": "total_transform"
                                        }
                                    ],
                                    "groupby": []
                                },
                                {
                                    "calculate": "datum.aggregate_transform/datum.total_transform",
                                    "as": "pct_transform"
                                }
                            ]
                        },
                        {
                            "description": "pie data labels text mark layer",
                            "mark": {
                                "type": "text",
                                "fontSize": 12,
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "2"
                                },
                                "dx": {
                                    "expr": "0"
                                },
                                "baseline": {
                                    "expr": "'middle'"
                                },
                                "clip": false,
                                "outerRadius": {
                                    "expr": "0.5714285714285714 * (min(width, height) / 2)"
                                }
                            },
                            "encoding": {
                                "theta": {
                                    "field": "users",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "stack": true
                                },
                                "text": {
                                    "field": "users",
                                    "aggregate": "sum",
                                    "type": "quantitative",
                                    "format": {
                                        "format": "NUMBER",
                                        "columnType": "NUMBER",
                                        "numDecimalDigits": -1,
                                        "currency": "USD",
                                        "nanFormat": ""
                                    },
                                    "formatType": "NUMBER_FORMATTER"
                                },
                                "color": {
                                    "field": "plan",
                                    "scale": {
                                        "range": [
                                            "#4C78A8",
                                            "#F58518",
                                            "#E45756",
                                            "#72B7B2",
                                            "#54A24B",
                                            "#EECA3B",
                                            "#B279A2",
                                            "#FF9DA6",
                                            "#9D755D",
                                            "#BAB0AC"
                                        ]
                                    },
                                    "sort": {
                                        "field": "plan",
                                        "order": "ascending"
                                    },
                                    "legend": null,
                                    "title": null,
                                    "type": "ordinal"
                                },
                                "order": {
                                    "field": "plan",
                                    "sort": "ascending"
                                }
                            },
                            "transform": []
                        }
                    ]
                }
            ],
            "transform": []
        }
    ],
    "config": {
        "legend": {
            "orient": "top"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "legend_pointselection_0": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            },
            "click_pointselection_0": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            }
        },
        "columnNameMappings": {
            "CHART_FOLD_KEYS": "Column",
            "CHART_FOLD_VALUES": "Values"
        }
    }
}
""")
chart_freemium_vs_paid.datasets.layer00 = freemium_vs_paid.to_json(orient='records')
chart_freemium_vs_paid.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     select count(*) as churned_users
#     from supabase_funnel_supabase_funnel.int_monetization_metrics
#     where is_churned = true
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
churned_users
